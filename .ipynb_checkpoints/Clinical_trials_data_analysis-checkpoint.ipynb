# %%
import requests
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
r=requests.get("https://classic.clinicaltrials.gov/api/query/full_studies")

# %%
url = 'https://clinicaltrials.gov/api/query/study_fields?'
params = '&expr=cancer+AND+AREA[CompletionDate]RANGE[2019,MAX]&min_rnk=1&max_rank=10&fmt=csv&NStudiesFound'
fields = '&fields=OverallStatus%2CCompletionDate%2CCompletionDateType%2CResultsFirstPostDate%2CPrimaryCompletionDate%2CDispFirstPostDate'
df = pd.read_csv(url + params + fields,skiprows=10)
df.colu

# %%
df
# Out:
#     Rank           OverallStatus     CompletionDate CompletionDateType  \
# 0      1          Unknown status    August 31, 2020        Anticipated
# 1      2          Unknown status          June 2022        Anticipated
# 2      3          Unknown status   November 1, 2022        Anticipated
# 3      4              Recruiting      December 2028        Anticipated
# 4      5              Recruiting  December 31, 2050        Anticipated
# 5      6              Recruiting       July 1, 2023        Anticipated
# 6      7          Unknown status  December 31, 2022        Anticipated
# 7      8      Not yet recruiting  December 31, 2024        Anticipated
# 8      9              Recruiting       July 1, 2024        Anticipated
# 9     10          Unknown status     March 31, 2022        Anticipated
# 10    11          Unknown status      June 30, 2023        Anticipated
# 11    12              Recruiting  November 20, 2023        Anticipated
# 12    13          Unknown status  September 1, 2022        Anticipated
# 13    14  Active, not recruiting  December 31, 2022        Anticipated
# 14    15          Unknown status     September 2022        Anticipated
# 15    16              Recruiting      March 1, 2026        Anticipated
# 16    17          Unknown status     September 2022        Anticipated
# 17    18              Recruiting      December 2023        Anticipated
# 18    19      Not yet recruiting   November 1, 2022        Anticipated
# 19    20      Not yet recruiting   February 5, 2022        Anticipated
#
#     ResultsFirstPostDate PrimaryCompletionDate  DispFirstPostDate
# 0                    NaN         June 30, 2020                NaN
# 1                    NaN             June 2021                NaN
# 2                    NaN      November 1, 2021                NaN
# 3                    NaN         December 2028                NaN
# 4                    NaN     December 31, 2050                NaN
# 5                    NaN          July 1, 2023                NaN
# 6                    NaN     December 31, 2022                NaN
# 7                    NaN        March 30, 2024                NaN
# 8                    NaN       January 1, 2024                NaN
# 9                    NaN     December 31, 2021                NaN
# 10                   NaN        March 31, 2023                NaN
# 11                   NaN          May 20, 2023                NaN
# 12                   NaN     September 1, 2022                NaN
# 13                   NaN       August 22, 2022                NaN
# 14                   NaN              May 2020                NaN
# 15                   NaN      November 1, 2024                NaN
# 16                   NaN           August 2022                NaN
# 17                   NaN         December 2023                NaN
# 18                   NaN     September 1, 2022                NaN
# 19                   NaN      February 5, 2022                NaN

# %%
# the ammount of cancer clinical trials made ussing different types of endoscopies 
expr='cancer'
procedures= ["endoscopy", "colonoscopy","bronchoscopy","arthroscopy","cystoscopy","hysteroscopy"]
url='https://classic.clinicaltrials.gov/api/query/field_values?expr='
search_elig_crit='+AND+SEARCH[Study](AREA[EligibilityCriteria]'
search_date='+AND+AREA[CompletionDate]RANGE[2019,MAX])'
params='&field=Condition&fmt=xml'
cancer_values=[]
for procedure in procedures:
    cancer_values.append(int(pd.read_xml(url+expr+search_elig_crit+procedure+search_date+params).NStudiesFound.dropna()))
cancer_values
# Out:
# [1859, 821, 226, 11, 187, 47]

# %%
plot=sns.barplot(x=procedures, y=cancer_values)
plot.set_xticklabels(plot.get_xticklabels(), rotation=30)
plot.set(title="Cancer clinical trials")
# Out:
# [Text(0.5, 1.0, 'Cancer clinical trials')]

# %%
expr='ALL'
procedures= ["endoscopy", "colonoscopy","bronchoscopy","arthroscopy","cystoscopy","hysteroscopy"]
url='https://classic.clinicaltrials.gov/api/query/field_values?expr='
search_elig_crit='+AND+SEARCH[Study](AREA[EligibilityCriteria]'
search_date='+AND+AREA[CompletionDate]RANGE[2019,MAX])'
params='&field=Condition&fmt=xml'
values=[]
for procedure in procedures:
    values.append(int(pd.read_xml(url+expr+search_elig_crit+procedure+search_date+params).NStudiesFound.dropna()))
values
# Out:
# [4055, 1526, 535, 474, 293, 231]

# %%
plot=sns.barplot(x=procedures, y=values)
plot.set_xticklabels(plot.get_xticklabels(), rotation=30)
plot.set(title='All clinical trials')
# Out:
# [Text(0.5, 1.0, 'All clinical trials')]

# %%
years= ["2015,2016","2017,2018","2019,2020","2021,2022","2023,2024"]
url='https://classic.clinicaltrials.gov/api/query/field_values?expr=ALL'
search_elig_crit='+AND+SEARCH[Study](AREA[EligibilityCriteria]'
search_years='+AND+AREA[CompletionDate]RANGE['
params='])&field=Condition&fmt=xml'
bronch_values, ar_values, cy_values, hy_values=[],[],[],[]
for year in years:
    bronch_values.append(int(pd.read_xml(url+search_elig_crit+'bronchoscopy'+search_years+year+params).NStudiesFound.dropna()))
    ar_values.append(int(pd.read_xml(url+search_elig_crit+'arthroscopy'+search_years+year+params).NStudiesFound.dropna()))
    cy_values.append(int(pd.read_xml(url+search_elig_crit+'cystoscopy'+search_years+year+params).NStudiesFound.dropna()))
    hy_values.append(int(pd.read_xml(url+search_elig_crit+'hysteroscopy'+search_years+year+params).NStudiesFound.dropna()))
print(bronch_values,ar_values,cy_values,hy_values,sep='\n')
# Out:
# [45, 59, 70, 59, 100]
# [47, 41, 69, 61, 85]
# [15, 25, 39, 30, 36]
# [29, 31, 33, 34, 38]

# %%
plt.plot(bronch_values,marker='o',linestyle='--',label='bronchoscopy')
plt.plot(ar_values,marker='o',linestyle='--',label='arthroscopy')
plt.plot(cy_values,marker='o',linestyle='--',label='cystoscopy')
plt.plot(hy_values,marker='o',linestyle='--',label='hysteroscopy')
plt.title('Use of different endoscopies in clinical trials over the years')
plt.legend()
plt.xticks(np.arange(len(years)),years)
plt.show()

# %%
url = 'https://clinicaltrials.gov/api/query/study_fields?'
params = '&expr=ALL+AND+AREA[CompletionDate]RANGE[2019,MAX]&min_rnk=1&max_rank=1000&fmt=csv&NStudiesFound'
fields = '&fields=OverallStatus'
df = pd.read_csv(url + params + fields,skiprows=10)
print(df['OverallStatus'].unique())
# Out:
# ['Recruiting' 'Completed' 'Not yet recruiting' 'Enrolling by invitation']

# %%
params='&expr=ALL+AND+SEARCH[Study](AREA[OverallStatus]recruiting)&min_rnk=1&max_rank=1000&fmt=csv&NStudiesFound'
df = pd.read_csv(url + params + fields,skiprows=10)
print(df['OverallStatus'].unique())
# Out:
# ['Recruiting']

# %%
params='&expr=ALL+AND+SEARCH[Study](AREA[OverallStatus]NOT+completed+AND+AREA[OverallStatus]NOT+invitation)&min_rnk=1&max_rank=1000&fmt=csv&NStudiesFound'
df = pd.read_csv(url + params + fields,skiprows=10)
print(df['OverallStatus'].unique())
# Out:
# ['Recruiting' 'Not yet recruiting']

# %%
params='&expr=ALL+AND+SEARCH[Study](AREA[OverallStatus]re)&min_rnk=1&max_rank=1000&fmt=csv&NStudiesFound'
df = pd.read_csv(url + params + fields,skiprows=10)
print(df['OverallStatus'].unique())
# 2 letter search
# Out:
# []

# %%
params='&expr=ALL+AND+SEARCH[Study](AREA[OverallStatus]unk)&min_rnk=1&max_rank=1000&fmt=csv&NStudiesFound'
df = pd.read_csv(url + params + fields,skiprows=10)
print(df['OverallStatus'].unique())
#first 3 letters search
# Out:
# ['Unknown status']

# %%
params='&expr=ALL+AND+SEARCH[Study](AREA[OverallStatus]ing)&min_rnk=1&max_rank=1000&fmt=csv&NStudiesFound'
df = pd.read_csv(url + params + fields,skiprows=10)
print(df['OverallStatus'].unique())
#last 3 letters search
# Out:
# []

# %%
params='&expr=ALL+AND+SEARCH[Study](AREA[OverallStatus]cru)&min_rnk=1&max_rank=1000&fmt=csv&NStudiesFound'
df = pd.read_csv(url + params + fields,skiprows=10)
print(df['OverallStatus'].unique())
#middle 3 letter search
# Out:
# []

# %%
scans=['endoscopy','CT','ultrasound','MRI','X-ray','fluoroscopy','PET']
url_all='https://classic.clinicaltrials.gov/api/query/field_values?expr=ALL'
search_elig_crit='+AND+SEARCH[Study](AREA[EligibilityCriteria]'
search_date='+AND+AREA[CompletionDate]RANGE[2019,MAX])'
params='&field=Condition&fmt=xml'
scan_values=[]
for scan in scans:
    scan_values.append(int(pd.read_xml(url_all+search_elig_crit+scan+search_date+params).NStudiesFound.dropna()))
scan_values
#Using Ct-Scans instead of CT returns 14,876 results instead of 15,305 ... seems legit
# Out:
# [4055, 15305, 6394, 20185, 5607, 84, 4472]

# %%
scans_sorted=[x for _,x in sorted(zip(scan_values,scans),reverse=True)]
scan_values_sorted=sorted(scan_values,reverse=True)
plot=sns.barplot(x=scans_sorted, y=scan_values_sorted)
plot.set_xticklabels(plot.get_xticklabels(), rotation=30)
plot.set(title='Different types of scans used in clinical trials (>2019)')
# Out:
# [Text(0.5, 1.0, 'Different types of scans used in clinical trials (>2019)')]

# %%
url_all='https://classic.clinicaltrials.gov/api/query/field_values?expr=ALL'
search_elig_crit='+AND+SEARCH[Study](AREA[EligibilityCriteria]'
search_status='+AND+AREA[OverallStatus]'
params=')&field=Condition&fmt=xml'
scan_values_in_progress, scan_values_completed, scan_values_unknown =[],[],[]
for scan in scans_sorted:
    scan_values_in_progress.append(int(pd.read_xml(url_all+search_elig_crit+scan+search_status+
                                                   'NOT+completed+AND+AREA[OverallStatus]NOT+unknown'
                                                   +params).NStudiesFound.dropna()))
    scan_values_completed.append(int(pd.read_xml(url_all+search_elig_crit+scan+search_status+
                                                   'completed'+params).NStudiesFound.dropna()))
    scan_values_unknown.append(int(pd.read_xml(url_all+search_elig_crit+scan+search_status+
                                                   'unknown'+params).NStudiesFound.dropna()))
print(scan_values_in_progress,scan_values_completed,scan_values_unknown,sep='\n')
# Out:
# [15739, 12076, 4372, 3976, 3715, 2849, 67]
# [13019, 9855, 4688, 6150, 2170, 3094, 57]
# [3886, 3361, 1781, 1293, 621, 1090, 18]

# %%
x=np.arange(len(scans_sorted))
plt.bar(x-0.3,scan_values_in_progress , 0.3, label = 'In progress',color='steelblue')
plt.bar(x, scan_values_completed, 0.3, label = 'Completed',color='orange')
plt.bar(x+0.3, scan_values_unknown, 0.3, label = 'Unknown',color='forestgreen')
plt.xticks(x,scans_sorted,rotation=30)
plt.title('Scans used in clinical trials')
plt.legend()
plt.show()

# %%
years=range(2016,2024)
search_elig_crit='+AND+SEARCH[Study](AREA[EligibilityCriteria]'
search_status_date='+AND+AREA[OverallStatus]NOT+unknown+AND+AREA[CompletionDate]'
params=')&field=Condition&fmt=xml'

scans_over_time=np.zeros((len(scans),len(years)))
i=0
for i in range(len(scans)):
    for year in years:
        scans_over_time[i][year-2016]=int(pd.read_xml(url_all+search_elig_crit+scans[i]+
                                                  search_status_date+str(year)+params).NStudiesFound.dropna())

scans_over_time
# Out:
# array([[2.500e+02, 2.960e+02, 3.070e+02, 3.280e+02, 2.890e+02, 2.860e+02,
#         3.910e+02, 6.070e+02],
#        [8.100e+02, 8.320e+02, 8.580e+02, 9.640e+02, 1.026e+03, 1.043e+03,
#         1.281e+03, 2.156e+03],
#        [3.930e+02, 4.010e+02, 4.270e+02, 4.830e+02, 4.890e+02, 4.890e+02,
#         5.930e+02, 1.014e+03],
#        [1.210e+03, 1.230e+03, 1.354e+03, 1.420e+03, 1.398e+03, 1.322e+03,
#         1.661e+03, 2.951e+03],
#        [4.450e+02, 4.370e+02, 4.560e+02, 5.050e+02, 5.000e+02, 5.840e+02,
#         5.830e+02, 9.090e+02],
#        [2.000e+00, 5.000e+00, 7.000e+00, 5.000e+00, 6.000e+00, 6.000e+00,
#         8.000e+00, 1.000e+01],
#        [2.300e+02, 2.320e+02, 2.250e+02, 2.870e+02, 2.620e+02, 2.590e+02,
#         3.370e+02, 6.820e+02]])

# %%
i=0
for scan_type in scans_over_time:
    plt.plot(scan_type,label=scans[i],marker='o',linestyle='--')
    i=i+1
plt.legend()
plt.title('Use of scans in clinical trials over the years')
plt.xlabel('years')
plt.xticks(np.arange(len(years)),years)
plt.show()

# %%
body_parts=['brain','heart','liver','eye','stomach','lung','kidney']
url_all='https://classic.clinicaltrials.gov/api/query/field_values?expr=ALL'
search_description='+AND+SEARCH[Study](AREA[DetailedDescription]'
search_date='+AND+AREA[CompletionDate]RANGE[2019,MAX])'
params='&field=Condition&fmt=xml'
body_part_values=[]
for body_part in body_parts:
    body_part_values.append(int(pd.read_xml(url_all+search_description+body_part+search_date+params).NStudiesFound.dropna()))
body_part_values
# Out:
# [11294, 17200, 6170, 4678, 3231, 11517, 8130]

# %%
body_parts_sorted=[x for _,x in sorted(zip(body_part_values,body_parts),reverse=True)]
body_part_values_sorted=sorted(body_part_values,reverse=True)
plot=sns.barplot(x=body_parts_sorted, y=body_part_values_sorted)
plot.set_xticklabels(plot.get_xticklabels(), rotation=30)
plot.set(title='Body parts targeted in clinical trials (>2019)')
# Out:
# [Text(0.5, 1.0, 'Body parts targeted in clinical trials (>2019)')]

# %%
years=range(2016,2024)
search_description='+AND+SEARCH[Study](AREA[DetailedDescription]'
search_status_date='+AND+AREA[OverallStatus]NOT+unknown+AND+AREA[CompletionDate]'
params=')&field=Condition&fmt=xml'

body_over_time=np.zeros((len(body_parts),len(years)))
i=0
for i in range(len(body_parts)):
    for year in years:
        body_over_time[i][year-2016]=int(pd.read_xml(url_all+search_description+body_parts[i]+
                                                  search_status_date+str(year)+params).NStudiesFound.dropna())

body_over_time
# Out:
# array([[ 681.,  788.,  858.,  961.,  870.,  853., 1100., 1870.],
#        [1253., 1346., 1485., 1593., 1567., 1508., 1861., 2908.],
#        [ 416.,  410.,  493.,  522.,  516.,  486.,  619.,  958.],
#        [ 331.,  405.,  410.,  483.,  430.,  438.,  567.,  800.],
#        [ 233.,  230.,  256.,  298.,  264.,  269.,  340.,  445.],
#        [ 699.,  729.,  880.,  958., 1026.,  993., 1181., 1825.],
#        [ 557.,  598.,  640.,  685.,  731.,  704.,  832., 1278.]])

# %%
i=0
for body_part in body_over_time:
    plt.plot(body_part,label=body_parts[i],marker='o',linestyle='--')
    i=i+1
plt.legend()
plt.title('Use of scans in clinical trials over the years')
plt.xlabel('years')
plt.xticks(np.arange(len(years)),years)
plt.show()

# %%
search_description='+AND+SEARCH[Study](AREA[DetailedDescription]'
search_elig_crit='+AND+AREA[EligibilityCriteria]'
search_date='+AND+AREA[CompletionDate]RANGE[2019,MAX])'
params='&field=Condition&fmt=xml'
body_part_values_endoscopy=[]
body_part_values_MRI=[]
body_part_values_CT=[]
body_part_values_ultrasound=[]
for body_part in body_parts_sorted:
    body_part_values_endoscopy.append(int(pd.read_xml(url_all+search_description+body_part+search_elig_crit+
                                                      'endoscopy'+search_date+params).NStudiesFound.dropna()))
    body_part_values_MRI.append(int(pd.read_xml(url_all+search_description+body_part+search_elig_crit+
                                                      'MRI'+search_date+params).NStudiesFound.dropna()))
    body_part_values_CT.append(int(pd.read_xml(url_all+search_description+body_part+search_elig_crit+
                                                      'CT'+search_date+params).NStudiesFound.dropna()))
    if body_part=='heart':
        body_part_values_ultrasound.append(int(pd.read_xml(url_all+search_description+body_part+search_elig_crit+
                                                      '(ultrasound+OR+echocardiogram)'+search_date+params).NStudiesFound.dropna()))
    else:
        body_part_values_ultrasound.append(int(pd.read_xml(url_all+search_description+body_part+search_elig_crit+
                                                      'ultrasound'+search_date+params).NStudiesFound.dropna()))
    
print(body_part_values_MRI,body_part_values_endoscopy,body_part_values_CT,body_part_values_ultrasound,sep='\n')
# Out:
# [1169, 866, 3406, 561, 768, 242, 242]
# [111, 113, 59, 101, 222, 38, 484]
# [696, 1479, 803, 550, 609, 95, 372]
# [1322, 319, 211, 224, 420, 66, 129]

# %%
x=np.arange(len(body_parts_sorted))
plt.bar(x-0.3,body_part_values_endoscopy,0.2,label='endoscopy',color='steelblue')
plt.bar(x-0.1,body_part_values_MRI,0.2,label='MRI',color='orange')
plt.bar(x+0.1,body_part_values_CT,0.2,label='CT',color='forestgreen')
plt.bar(x+0.3,body_part_values_ultrasound,0.2,label='ultrasound',color='firebrick')
plt.xticks(x,body_parts_sorted)
plt.title('Clinical Trials for different body using different scans (>2019)')
plt.legend()
plt.show()

# %%
ultrasounds=['uterus','obstetric','breast','carotid','musculoskeletal','pelvic','kidney','gallbladder','spleen','pancreas',
             'prostate','scrotum','thyroid','venous','heart','liver','renal','vascular','abdominal','vaginal','rectal']
url_all='https://classic.clinicaltrials.gov/api/query/field_values?expr=ALL'
search_elig_crit='+AND+SEARCH[Study](AREA[EligibilityCriteria]('
search_date=')+AND+AREA[CompletionDate]RANGE[2019,MAX])'
params='&field=Condition&fmt=xml'
ultrasound_values=[]
for ultrasound in ultrasounds:
    if ultrasound=='uterus':
        ultrasound_values.append(int(pd.read_xml(url_all+search_elig_crit+ultrasound+'+ultrasound+OR+'+ultrasound+'+sonography'+
                                                 '+OR+hysterosonography+OR+sonohysterography'+search_date+params
                                                ).NStudiesFound.dropna()))
    elif ultrasound=='heart':
        ultrasound_values.append(int(pd.read_xml(url_all+search_elig_crit+ultrasound+'+ultrasound+OR+'+ultrasound+'+sonography'+
                                                 '+OR+echocardiogram'+search_date+params
                                                ).NStudiesFound.dropna()))
    else:
        ultrasound_values.append(int(pd.read_xml(url_all+search_elig_crit+ultrasound+'+ultrasound+OR+'+ultrasound+'+sonography'+
                                                 search_date+params).NStudiesFound.dropna()))
ultrasound_values
# Out:
# [665,
#  62,
#  1006,
#  215,
#  61,
#  608,
#  1982,
#  83,
#  101,
#  251,
#  451,
#  5,
#  500,
#  861,
#  4838,
#  1909,
#  1933,
#  753,
#  895,
#  269,
#  221]

# %%
ultrasounds_sorted=[x for _,x in sorted(zip(ultrasound_values,ultrasounds),reverse=True)]
ultrasound_values_sorted=sorted(ultrasound_values,reverse=True)
plt.barh(ultrasounds_sorted,ultrasound_values_sorted)
plt.title('Ultrasounds used in clinical trials (>2019)')
plt.show()

# %%
url='https://classic.clinicaltrials.gov/api/query/study_fields?expr=echocardiogram'
search_elig_crit_heart='+AND+SEARCH[Study](AREA[EligibilityCriteria](heart+ultrasound+OR+heart+sonography+OR+echocardiogram)'
search_date_heart='+AND+AREA[CompletionDate]RANGE[2019,MAX])'
params='&min_rnk&max_rnk=1000&fields=Condition&fmt=csv'
df_heart=pd.read_csv(url+search_elig_crit_heart+search_date_heart+params,skiprows=10)
heart_diseases=df_heart['Condition'].unique().tolist()
big_string=''
for heart_disease in heart_diseases:
    big_string+=heart_disease+' '

words=list(big_string.replace('|',' ').split(' '))
words_frequency=[words.count(word) for word in words]
dic=dict(zip(words,words_frequency))
del dic['Cardiovascular'],dic['Heart'],dic['of'],dic['on'], dic['to'], dic['-'], dic['19'], dic['and'], dic['in'], dic['the']
del dic['Cancer,'], dic['Female'], dic['Echocardiography'], dic['Pacemaker'], dic['With']
dic={key:value for key,value in dic.items() if value >4}
sorted(dic.items(),key=lambda x:x[1],reverse=True)
# Out:
# [('Failure', 110),
#  ('Disease', 102),
#  ('Valve', 95),
#  ('Aortic', 69),
#  ('Regurgitation', 57),
#  ('Pulmonary', 57),
#  ('Mitral', 56),
#  ('Ventricular', 53),
#  ('Cardiac', 52),
#  ('Cardiomyopathy', 49),
#  ('Diseases', 46),
#  ('Cancer', 45),
#  ('Hypertension', 44),
#  ('Left', 44),
#  ('Stenosis', 41),
#  ('Dysfunction', 40),
#  ('Myocardial', 39),
#  ('Acute', 39),
#  ('Breast', 37),
#  ('Congenital', 29),
#  ('Recurrent', 27),
#  ('Atrial', 26),
#  ('Ejection', 24),
#  ('Fraction', 24),
#  ('Coronary', 23),
#  ('Syndrome', 23),
#  ('Chronic', 23),
#  ('Leukemia', 22),
#  ('Infarction', 21),
#  ('Tricuspid', 21),
#  ('Ischemic', 21),
#  ('Diastolic', 19),
#  ('Fibrillation', 19),
#  ('Hypertrophic', 18),
#  ('Insufficiency', 17),
#  ('Artery', 16),
#  ('Functional', 16),
#  ('Amyloidosis', 15),
#  ('Carcinoma', 15),
#  ('Stage', 15),
#  ('Systolic', 14),
#  ('Myeloid', 14),
#  ('Stroke', 13),
#  ('Failure,', 13),
#  ('Preserved', 13),
#  ('Cardiotoxicity', 13),
#  ('Neoplasm', 13),
#  ('Right', 12),
#  ('Lymphoma', 12),
#  ('Dilated', 11),
#  ('Malignant', 11),
#  ('Shock', 11),
#  ('Refractory', 11),
#  ('AJCC', 11),
#  ('Cell', 10),
#  ('Patent', 10),
#  ('Metastatic', 10),
#  ('v8', 10),
#  ('Obstructive', 9),
#  ('Valvular', 9),
#  ('Diabetes', 9),
#  ('Embolism', 9),
#  ('Reduced', 9),
#  ('Block', 8),
#  ('Arterial', 8),
#  ('Children', 8),
#  ('Systemic', 8),
#  ('Melanoma', 8),
#  ('Therapy', 7),
#  ('Cardiomyopathy,', 7),
#  ('STEMI', 7),
#  ('Toxicity', 7),
#  ('2', 7),
#  ('Septic', 7),
#  ('Primary', 7),
#  ('Kidney', 7),
#  ('III', 7),
#  ('IV', 7),
#  ('Healthy', 6),
#  ('Surgery', 6),
#  ('Arrhythmia', 6),
#  ('Thrombosis', 6),
#  ('Septal', 6),
#  ('Type', 6),
#  ('Solid', 6),
#  ('Unresectable', 6),
#  ('Transcatheter', 6),
#  ('Diffuse', 6),
#  ('Cholangiocarcinoma', 6),
#  ('Complication', 5),
#  ('Defect', 5),
#  ('Ductus', 5),
#  ('Arteriosus', 5),
#  ('Ischemia', 5),
#  ('Pediatric', 5),
#  ('Cardiomyopathies', 5),
#  ('Foramen', 5),
#  ('Degenerative', 5),
#  ('Elevation', 5),
#  ('Tetralogy', 5),
#  ('Fallot', 5),
#  ('Disorders', 5),
#  ('Positive', 5),
#  ('Transthyretin', 5),
#  ('Abnormalities', 5),
#  ('Cardiogenic', 5),
#  ('Duchenne', 5),
#  ('Muscular', 5),
#  ('Congestive', 5),
#  ('Aneurysm', 5),
#  ('Follicular', 5)]

# %%
heart_zones=['tricuspid','ventricle','aorta','pulmonary+artery','atrium','aortic','mitral','coronary+artery']
url_all='https://classic.clinicaltrials.gov/api/query/field_values?expr=ALL'
search_ult_heart='+AND+SEARCH[Study](AREA[EligibilityCriteria](heart+ultrasound+OR+heart+sonography+OR+echocardiogram)'
search_zone='+AND+AREA[Condition]'
search_date='+AND+AREA[CompletionDate]RANGE[2019,MAX])'
params='&field=Condition&fmt=xml'
heart_zone_values=[]
for heart_zone in heart_zones:
    heart_zone_values.append(int(pd.read_xml(url_all+search_ult_heart+search_zone+heart_zone+search_date+
                                           params).NStudiesFound.dropna()))
heart_zone_values
# Out:
# [45, 117, 150, 34, 228, 150, 108, 87]

# %%
heart_zones=[heart_zone.replace('+',' ') for heart_zone in heart_zones]
plt.pie(heart_zone_values,labels=heart_zones,explode=[0,0,0,0,0.2,0,0,0])
plt.title('Echocardiograms made in Clinical Trials by zones (>2019)')
plt.show()

# %%
heart_diseases=['pulmonary','regurgitation','cardiomyopathy','hypertension','stenosis','myocardial','breast',
                'coronary+syndrome','leukemia','diastolic','atrial+fibrillation','hypertrophy','amyloidosis',
               'systolic','carcinoma','lymphoma']
url_all='https://classic.clinicaltrials.gov/api/query/field_values?expr=ALL'
search_ult_heart='+AND+SEARCH[Study](AREA[EligibilityCriteria](heart+ultrasound+OR+heart+sonography+OR+echocardiogram)'
search_disease='+AND+AREA[Condition]'
search_date='+AND+AREA[CompletionDate]RANGE[2019,MAX])'
params='&field=Condition&fmt=xml'
heart_disease_values=[]
for heart_disease in heart_diseases:
    heart_disease_values.append(int(pd.read_xml(url_all+search_ult_heart+search_disease+heart_disease+search_date+
                                           params).NStudiesFound.dropna()))
heart_disease_values
# Out:
# [350, 130, 121, 141, 136, 93, 447, 16, 465, 32, 206, 53, 54, 31, 346, 424]

# %%
heart_diseases_sorted=[x.replace('tolic','tolic dysfunction/heart failure') for _,x in sorted(zip(heart_disease_values,heart_diseases),reverse=True)]
heart_diseases_sorted=[x.replace('+',' ') for x in heart_diseases_sorted]
heart_diseases_sorted=[x.replace('tation','tation mitral/aortic/tricuspid') for x in heart_diseases_sorted]
heart_diseases_sorted=[x.replace('breast','breast cancer') for x in heart_diseases_sorted]
heart_diseases_sorted=[x.replace('pulmonary','pulmonary related diseases') for x in heart_diseases_sorted]
plt.barh(heart_diseases_sorted,sorted(heart_disease_values,reverse=True))
plt.title('Echocardiograms made in Clinical Trials by diseases (>2019)')
plt.show()

# %%
url_sample='https://classic.clinicaltrials.gov/api/query/study_fields?expr=ALL'
search_sponsor_sample='+AND+SEARCH[Study](AREA[EligibilityCriteria](ultrasound+OR+echocardiogram)+AND+AREA[LeadSponsorClass]INDUSTRY'
search_date='+AND+AREA[CompletionDate]RANGE[2019,MAX])'
params_sample='&min_rnk&max_rnk=1000&fields=LeadSponsorClass%2CLeadSponsorName&fmt=csv'
df_sponsor=pd.read_csv(url_sample+search_sponsor_sample+search_date+params_sample,skiprows=10)
companies=df_sponsor.LeadSponsorName.tolist()
company_freq=[companies.count(company) for company in df_sponsor.LeadSponsorName]
sample_companies=[company.replace(' ','+').replace('&','%26') for company,freq in list(set(zip(companies,company_freq))) if freq >5]
sample_companies
# Out:
# ['Hoffmann-La+Roche',
#  'AstraZeneca',
#  'Pfizer',
#  'Boston+Scientific+Corporation',
#  'Janssen+Research+%26+Development,+LLC',
#  'Novartis+Pharmaceuticals',
#  'GlaxoSmithKline',
#  'Ferring+Pharmaceuticals',
#  'Amgen',
#  'Bayer',
#  'AbbVie',
#  'Lifetech+Scientific+(Shenzhen)+Co.,+Ltd.',
#  'Abbott+Medical+Devices',
#  'Myovant+Sciences+GmbH',
#  'Eko+Devices,+Inc.',
#  'Kite,+A+Gilead+Company',
#  'Celgene',
#  'Bristol-Myers+Squibb',
#  'Sumitomo+Pharma+Oncology,+Inc.',
#  'Jiangsu+HengRui+Medicine+Co.,+Ltd.',
#  'InSightec',
#  'Medtronic+Cardiovascular']

# %%
url='https://classic.clinicaltrials.gov/api/query/field_values?expr=ALL'
search_sponsor='+AND+SEARCH[Study](AREA[EligibilityCriteria](ultrasound+OR+echocardiogram)+AND+AREA[LeadSponsorName]'
params='&field=Condition&fmt=xml'
sponsor_values=[]
for company in sample_companies:
    sponsor_values.append(int(pd.read_xml(url+search_sponsor+company+search_date+params).NStudiesFound.dropna()))

# %%
companies_sorted=[x.replace('+',' ').replace('%26','&') for _,x in sorted(zip(sponsor_values,sample_companies),reverse=True)]
plt.barh(companies_sorted,sorted(sponsor_values,reverse=True))
plt.title('Top Industry Sponsors for Ultrasound Clinical Trials (>2019)')
plt.show()

# %%
url_sample='https://classic.clinicaltrials.gov/api/query/study_fields?expr=ALL'
search_sponsor_sample='+AND+SEARCH[Study](AREA[LeadSponsorClass]INDUSTRY+AND+AREA[EligibilityCriteria]('
search_date=')+AND+AREA[CompletionDate]RANGE[2019,MAX])'
params_sample='&min_rnk&max_rnk=1000&fields=LeadSponsorClass%2CLeadSponsorName&fmt=csv'
ultrasounds=['heart','kidney','renal','liver','breast','abdominal','venous']
sponsor_ultra=[]
for ultrasound in ultrasounds:
    if ultrasound=='heart':
        df_sponsor=pd.read_csv(url_sample+search_sponsor_sample+ultrasound+'+ultrasound+OR+'+ultrasound+
                               '+sonography+OR+echocardiography'+search_date+params_sample,skiprows=10)
    else:
        df_sponsor=pd.read_csv(url_sample+search_sponsor_sample+ultrasound+'+ultrasound+OR+'+ultrasound+'+sonography'+
                               search_date+params_sample,skiprows=10)
    companies=df_sponsor.LeadSponsorName.tolist()
    company_freq=[companies.count(company) for company in df_sponsor.LeadSponsorName]
    sponsor_ultra.append([company.replace(' ','+').replace('&','%26') for _,company 
                          in list(sorted(set(zip(company_freq,companies)),reverse=True))][:10])
sponsor_ultra
# Out:
# [['Novartis+Pharmaceuticals',
#   'Abbott+Medical+Devices',
#   'Jiangsu+HengRui+Medicine+Co.,+Ltd.',
#   'Hoffmann-La+Roche',
#   'Boston+Scientific+Corporation',
#   'AstraZeneca',
#   'Edwards+Lifesciences',
#   'Medtronic+Cardiovascular',
#   'Bristol-Myers+Squibb',
#   'Chongqing+Precision+Biotech+Co.,+Ltd'],
#  ['InSightec',
#   'Jiangsu+HengRui+Medicine+Co.,+Ltd.',
#   'Shanghai+MicroPort+Medical+(Group)+Co.,+Ltd.',
#   'Chia+Tai+Tianqing+Pharmaceutical+Group+Co.,+Ltd.',
#   'Ferring+Pharmaceuticals',
#   'ViiV+Healthcare',
#   'Sunshine+Lake+Pharma+Co.,+Ltd.',
#   'AstraZeneca',
#   'Pfizer',
#   'Caliway+Biopharmaceuticals+Co.,+Ltd.'],
#  ['InSightec',
#   'Jiangsu+HengRui+Medicine+Co.,+Ltd.',
#   'Shanghai+MicroPort+Medical+(Group)+Co.,+Ltd.',
#   'Ferring+Pharmaceuticals',
#   'Chia+Tai+Tianqing+Pharmaceutical+Group+Co.,+Ltd.',
#   'Sunshine+Lake+Pharma+Co.,+Ltd.',
#   'Pfizer',
#   'Caliway+Biopharmaceuticals+Co.,+Ltd.',
#   'Bayer',
#   'AstraZeneca'],
#  ['Jiangsu+HengRui+Medicine+Co.,+Ltd.',
#   'Chia+Tai+Tianqing+Pharmaceutical+Group+Co.,+Ltd.',
#   'InSightec',
#   'ViiV+Healthcare',
#   'Sunshine+Lake+Pharma+Co.,+Ltd.',
#   'Vigonvita+Life+Sciences',
#   'Takeda',
#   'Pfizer',
#   'Ferring+Pharmaceuticals',
#   'CSPC+ZhongQi+Pharmaceutical+Technology+Co.,+Ltd.'],
#  ['Ferring+Pharmaceuticals',
#   'AstraZeneca',
#   'Shanghai+Henlius+Biotech',
#   'Real+Imaging+Ltd.',
#   'Jiangsu+HengRui+Medicine+Co.,+Ltd.',
#   'Estetra',
#   'CicloMed+LLC',
#   'Chia+Tai+Tianqing+Pharmaceutical+Group+Co.,+Ltd.',
#   'Celgene',
#   'Carmat+SA'],
#  ['Jiangsu+HengRui+Medicine+Co.,+Ltd.',
#   'Sunshine+Lake+Pharma+Co.,+Ltd.',
#   'Chia+Tai+Tianqing+Pharmaceutical+Group+Co.,+Ltd.',
#   'CSPC+ZhongQi+Pharmaceutical+Technology+Co.,+Ltd.',
#   'Qilu+Pharmaceutical+Co.,+Ltd.',
#   'Wuhan+Createrna+Science+and+Technology+Co.,+Ltd',
#   'Vivasure+Medical+Limited',
#   'Taizhou+Mabtech+Pharmaceutical+Co.,Ltd',
#   'Suzhou+Yabao+Pharmaceutical+R%26D+Co.,+Ltd.',
#   'Keymed+Biosciences+Co.Ltd'],
#  ['Chia+Tai+Tianqing+Pharmaceutical+Group+Co.,+Ltd.',
#   'Jiangsu+HengRui+Medicine+Co.,+Ltd.',
#   'InSightec',
#   'Shanghai+MicroPort+Medical+(Group)+Co.,+Ltd.',
#   'Ferring+Pharmaceuticals',
#   'Abbott+Medical+Devices',
#   'AstraZeneca',
#   'Tesaro,+Inc.',
#   'Sunshine+Lake+Pharma+Co.,+Ltd.',
#   'Raziel+Therapeutics+Ltd.']]

# %%
url='https://classic.clinicaltrials.gov/api/query/field_values?expr=ALL'
search_ultrasound='+AND+SEARCH[Study](AREA[EligibilityCriteria]('
search_sponsor=')+AND+AREA[LeadSponsorName]'
search_date='+AND+AREA[LeadSponsorClass]INDUSTRY+AND+AREA[CompletionDate]RANGE[2019,MAX])'
params='&field=Condition&fmt=xml'
sponsor_values_ultrasound=[]
for ultrasound,ultrasound_companies in zip(ultrasounds,sponsor_ultra):
    sponsor_values=[]
    for company in ultrasound_companies:
        if ultrasound=='heart':
            sponsor_values.append(int(pd.read_xml(url+search_ultrasound+ultrasound+'+ultrasound+OR+echocardiography'+
                                                  ultrasound+'+sonography'+search_sponsor+company+search_date+
                                                  params).NStudiesFound.dropna())) 
        else:
            sponsor_values.append(int(pd.read_xml(url+search_ultrasound+ultrasound+'+ultrasound+OR+'+ultrasound+'+sonography'+
                                               search_sponsor+company+search_date+params).NStudiesFound.dropna())) 
         
    sponsor_values_ultrasound.append(sponsor_values)
sponsor_values_ultrasound
# Out:
# [[40, 26, 21, 36, 18, 31, 15, 15, 14, 13],
#  [29, 23, 9, 9, 8, 7, 7, 7, 6, 6],
#  [28, 19, 9, 8, 8, 6, 6, 6, 6, 6],
#  [21, 13, 10, 9, 7, 6, 6, 6, 6, 6],
#  [7, 4, 3, 3, 3, 3, 3, 3, 3, 3],
#  [30, 10, 5, 5, 4, 3, 3, 3, 3, 3],
#  [15, 10, 8, 6, 6, 6, 5, 4, 4, 4]]

# %%
for ultrasound,ultrasound_companies,sponsor_values in zip(ultrasounds,sponsor_ultra,sponsor_values_ultrasound):
    ultrasound_companies=[company.replace('+',' ') for value,company in 
                          sorted(zip(sponsor_values,ultrasound_companies),reverse=True) if value>4]
    sponsor_values=[value for value in sorted(sponsor_values,reverse=True) if value>4]
    plt.barh(ultrasound_companies,sponsor_values,label=ultrasound)
plt.legend()
plt.title('Top Industry Sponsors by Ultrasound Type in Clinical Trials (>2019)')
plt.show()

# %%
url='https://classic.clinicaltrials.gov/api/query/study_fields?expr=ALL'
search_elig_crit='+AND+SEARCH[Study](AREA[EligibilityCriteria](ultrasound+OR+echocardiogram)'
search_date='+AND+AREA[CompletionDate]RANGE[2019,MAX]+AND+AREA[LeadSponsorClass]INDUSTRY)'
params='&min_rnk&max_rnk=1000&fields=Condition&fmt=csv'
df_condition=pd.read_csv(url+search_elig_crit+search_date+params,skiprows=10)
conditions=df_condition['Condition'].unique().tolist()
big_string=''
for condition in conditions:
    big_string+=condition+' '

words=list(big_string.replace('|',' ').split(' '))
words_frequency=[words.count(word) for word in words]
dic=dict(zip(words,words_frequency))
dic={key:value for key,value in dic.items() if value >4}
sorted(dic.items(),key=lambda x:x[1],reverse=True)
# Out:
# [('Cancer', 176),
#  ('Breast', 79),
#  ('Disease', 74),
#  ('Lymphoma', 59),
#  ('Leukemia', 56),
#  ('Acute', 54),
#  ('Chronic', 53),
#  ('Heart', 51),
#  ('Cell', 51),
#  ('Carcinoma', 46),
#  ('of', 43),
#  ('Diseases', 42),
#  ('Failure', 42),
#  ('Valve', 35),
#  ('Lung', 34),
#  ('Aortic', 33),
#  ('Stage', 32),
#  ('Solid', 31),
#  ('Mitral', 30),
#  ('Stenosis', 28),
#  ('Liver', 28),
#  ('Advanced', 27),
#  ('Syndrome', 27),
#  ('Renal', 26),
#  ('Myeloid', 25),
#  ('and', 24),
#  ('Metastatic', 24),
#  ('Kidney', 24),
#  ('Regurgitation', 23),
#  ('Refractory', 22),
#  ('Tumor', 21),
#  ('Pulmonary', 21),
#  ('Atrial', 20),
#  ('Recurrent', 20),
#  ('Artery', 18),
#  ('Healthy', 18),
#  ('Tumors', 17),
#  ('Multiple', 17),
#  ('Large', 17),
#  ('Malignant', 17),
#  ('Lymphocytic', 16),
#  ('Ovarian', 16),
#  ('Diffuse', 16),
#  ('Adenocarcinoma', 15),
#  ('Gastric', 15),
#  ('Fibrillation', 14),
#  ('Neoplasms', 14),
#  ('Coronary', 14),
#  ('Small', 14),
#  ('Myelodysplastic', 14),
#  ('or', 14),
#  ('B-Cell', 14),
#  ('With', 13),
#  ('Insufficiency', 13),
#  ('Lymphoblastic', 13),
#  ('Gene', 13),
#  ('Melanoma', 13),
#  ('Primary', 13),
#  ('Type', 13),
#  ('Hepatitis', 12),
#  ('Relapsed', 12),
#  ('Hepatocellular', 12),
#  ('Myeloma', 12),
#  ('Neoplasm', 12),
#  ('Myelofibrosis', 12),
#  ('Ventricular', 12),
#  ('Pancreatic', 12),
#  ('B', 11),
#  ('Fistula', 11),
#  ('Prostate', 11),
#  ('B-cell', 11),
#  ('Squamous', 11),
#  ('Carotid', 10),
#  ('in', 10),
#  ('Head', 10),
#  ('Neck', 10),
#  ('Dystrophy', 10),
#  ('Diabetes', 10),
#  ('Female', 10),
#  ('Mutation', 9),
#  ('Muscular', 9),
#  ('Hodgkin', 9),
#  ('Pregnancy', 9),
#  ('Dysfunction', 9),
#  ('Hypertension', 9),
#  ('Uterine', 9),
#  ('Arterial', 9),
#  ('Cardiovascular', 8),
#  ('Venous', 8),
#  ('Infection', 8),
#  ('Non', 8),
#  ('Arteriovenous', 8),
#  ('Severe', 8),
#  ('End', 8),
#  ('Benign', 8),
#  ('Hepatic', 8),
#  ('Negative', 8),
#  ('Functional', 7),
#  ('Failure,', 7),
#  ('Risk', 7),
#  ('Adult', 7),
#  ('Bladder', 7),
#  ('IV', 7),
#  ('Neoplasms,', 7),
#  ('Follicular', 7),
#  ('to', 7),
#  ('Steatohepatitis', 7),
#  ('Vascular', 7),
#  ('Urinary', 7),
#  ('Tract', 7),
#  ('Thyroid', 7),
#  ('Obstructive', 7),
#  ('Cardiomyopathy', 7),
#  ('Knee', 7),
#  ('Diabetic', 7),
#  ('Impairment', 7),
#  ('Ulcer', 7),
#  ('Trisomy', 7),
#  ('Septal', 7),
#  ('1', 7),
#  ('Triple', 7),
#  ('Carcinoma,', 7),
#  ('Colorectal', 7),
#  ('Lymphoma,', 7),
#  ('Positive', 7),
#  ('AJCC', 7),
#  ('v8', 7),
#  ('Polycystic', 6),
#  ('Tricuspid', 6),
#  ('Symptomatic', 6),
#  ('Stroke', 6),
#  ('Menstrual', 6),
#  ('Phase', 6),
#  ('Respiratory', 6),
#  ('Amyloidosis', 6),
#  ('Catheter', 6),
#  ('Complications', 6),
#  ('Infertility', 6),
#  ('Peripheral', 6),
#  ('Skin', 6),
#  ('Pleural', 6),
#  ('T-cell', 6),
#  ('Left', 6),
#  ('Relapsed/Refractory', 6),
#  ('Defect', 6),
#  ('Related', 6),
#  ('Non-Hodgkin', 6),
#  ('Syndromes', 6),
#  ('High', 6),
#  ('Cancers', 6),
#  ('HER2', 6),
#  ('Rectal', 6),
#  ('Congenital', 5),
#  ('Autosomal', 5),
#  ('Subjects', 5),
#  ('Calcification', 5),
#  ('Cardiac', 5),
#  ('Heavy', 5),
#  ('Bleeding', 5),
#  ('NSCLC', 5),
#  ('Early', 5),
#  ('Non-Alcoholic', 5),
#  ('Fatty', 5),
#  ('Hypertrophic', 5),
#  ('Ejection', 5),
#  ('Fraction', 5),
#  ('Access', 5),
#  ('Complication', 5),
#  ('Prostatic', 5),
#  ('Lower', 5),
#  ('Fibroids', 5),
#  ('Preterm', 5),
#  ('Arthritis', 5),
#  ('Pain', 5),
#  ('Leukemia,', 5),
#  ('2', 5),
#  ('Stomach', 5),
#  ('Sleep', 5),
#  ('Foot', 5),
#  ('Essential', 5),
#  ('Disorders', 5),
#  ('Esophageal', 5),
#  ('Nonalcoholic', 5),
#  ('Fibrosis', 5),
#  ('Mantle', 5),
#  ('Gland', 5),
#  ('Mesothelioma', 5),
#  ('Cholangiocarcinoma', 5),
#  ('Systemic', 5)]

# %%
conditions=['cancer','stenosis','hepatitis','hypertension','steatohepatitis','cardiomyopathy','ulcer','fibrillation']
url_sample='https://classic.clinicaltrials.gov/api/query/study_fields?expr=ALL'
search_sponsor_sample='+AND+SEARCH[Study](AREA[LeadSponsorClass]INDUSTRY+AND+AREA[Condition]('
search_date=')+AND+AREA[EligibilityCriteria]ultrasound+AREA[CompletionDate]RANGE[2019,MAX])'
params_sample='&min_rnk&max_rnk=1000&fields=LeadSponsorClass%2CLeadSponsorName&fmt=csv'
sponsor_cond=[]
for condition in conditions:
    df_cond=pd.read_csv(url_sample+search_sponsor_sample+condition+search_date+params_sample,skiprows=10)
    companies=df_cond.LeadSponsorName.tolist()
    company_freq=[companies.count(company) for company in df_cond.LeadSponsorName]
    sponsor_cond.append([company.replace(' ','+').replace('&','%26') for freq,company 
                          in list(sorted(set(zip(company_freq,companies)),reverse=True))][:5])
sponsor_cond
# Out:
# [['Chia+Tai+Tianqing+Pharmaceutical+Group+Co.,+Ltd.',
#   'Jiangsu+HengRui+Medicine+Co.,+Ltd.',
#   'Tesaro,+Inc.',
#   'Precision+Biopsy,+Inc.',
#   'InSightec'],
#  ['Abbott+Medical+Devices',
#   'Silk+Road+Medical',
#   'Contego+Medical,+Inc.',
#   'W.L.Gore+%26+Associates',
#   'Shanghai+MicroPort+Rhythm+MedTech+Co.,+Ltd.'],
#  ['F-star+Therapeutics,+Inc.',
#   'AbbVie',
#   'Shanghai+HEP+Pharmaceutical+Co.,+Ltd.',
#   'Janssen+Research+%26+Development,+LLC',
#   'Huahui+Health'],
#  ['Takeda',
#   'SoniVie+Inc.',
#   'Solsys+Medical+LLC',
#   'Shanghai+Pharmaceuticals+Holding+Co.,+Ltd',
#   'ReCor+Medical,+Inc.'],
#  ['Zydus+Therapeutics+Inc.',
#   'Sunshine+Lake+Pharma+Co.,+Ltd.',
#   'Philips+Clinical+%26+Medical+Affairs+Global',
#   'Sonic+Incytes',
#   'Sagimet+Biosciences+Inc.'],
#  ['Ancora+Heart,+Inc.'],
#  ['RHEACELL+GmbH+%26+Co.+KG',
#   'MediWound+Ltd',
#   'Medaxis,+LLC',
#   'Beijing+Northland+Biotech.+Co.,+Ltd.',
#   'Aroa+Biosurgery+Limited'],
#  ['Javelin+Medical',
#   'InCarda+Therapeutics,+Inc.',
#   'Tempus+Labs',
#   'Sigknow+Biomedical+Co.,+Ltd.',
#   'Boston+Scientific+Corporation']]

# %%
url='https://classic.clinicaltrials.gov/api/query/field_values?expr=ALL'
search_sponsor='+AND+SEARCH[Study](AREA[EligibilityCriteria](ultrasound+OR+echocardiogram)+AND+AREA[LeadSponsorName]'
search_condition='+AND+AREA[Condition]'
search_date='+AND+AREA[CompletionDate]RANGE[2019,MAX]+AND+AREA[LeadSponsorClass]INDUSTRY)'
params='&field=Condition&fmt=xml'
sponsor_values_condition=[]
for condition,condition_companies in zip(conditions,sponsor_cond):
    sponsor_values=[]
    for company in condition_companies:
        sponsor_values.append(int(pd.read_xml(url+search_sponsor+company+search_condition+condition+search_date+
                                              params).NStudiesFound.dropna()))      
    sponsor_values_condition.append(sponsor_values)
sponsor_values_condition
# Out:
# [[17, 17, 4, 4, 4],
#  [12, 2, 3, 1, 1],
#  [4, 3, 2, 2, 2],
#  [2, 1, 1, 1, 1],
#  [2, 2, 2, 1, 1],
#  [2],
#  [4, 2, 2, 2, 2],
#  [2, 2, 1, 1, 5]]

# %%
for condition,condition_companies,sponsor_values in zip(conditions,sponsor_cond,sponsor_values_condition):
    condition_companies=[company.replace('+',' ').replace('%26','&') for value,company in 
                        sorted(zip(sponsor_values,condition_companies),reverse=True) if value>1]
    sponsor_values=[value for value in sorted(sponsor_values,reverse=True) if value>1]
    plt.barh(condition_companies,sponsor_values,label=condition)
plt.legend()
plt.title('Top Industry Sponsors by Condition Type in Clinical Trials (>2019)')
plt.show()

# %%
url_sample='https://classic.clinicaltrials.gov/api/query/study_fields?expr=ALL'
search_sponsor_sample='+AND+SEARCH[Study](AREA[EligibilityCriteria](ultrasound+OR+echocardiogram)'
search_date='+AND+AREA[CompletionDate]RANGE[2019,MAX])'
params_sample='&min_rnk&max_rnk=1000&fields=LeadSponsorClass%2CLeadSponsorName&fmt=csv'
df_all_sponsor=pd.read_csv(url_sample+search_sponsor_sample+search_date+params_sample,skiprows=10)

url='https://classic.clinicaltrials.gov/api/query/field_values?expr=ALL'
search_class_date='+AND+AREA[CompletionDate]RANGE[2019,MAX]+AND+AREA[LeadSponsorClass]'
params=')&field=Condition&fmt=xml'

sponsor_type_values=[]
sponsor_types=df_all_sponsor.LeadSponsorClass.unique().tolist()
for sponsor_type in sponsor_types:
    sponsor_type_values.append(int(pd.read_xml(url+search_sponsor_sample+search_class_date+sponsor_type+
                                               params).NStudiesFound.dropna()))
sponsor_type_values
# Out:
# [7884, 2649, 276, 272, 166, 24]

# %%
plt.pie(sponsor_type_values)
plt.title('Type of Investors in Clinical Trials (>2019)')
plt.legend(labels=sponsor_types,bbox_to_anchor=(1,1))
plt.show()
